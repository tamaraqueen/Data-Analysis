# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
zomato=pd.read_csv('C:\\Users\\Queen Tamara\\Downloads\\zomato.csv')

# %%
zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
zomato.shape
# Out:
# (51717, 17)

# %%
## data cleaning
zomato.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
feature_na=[feature for feature in zomato.columns if zomato[feature].isnull().sum()>0]
feature_na
# Out:
# ['rate',
#  'phone',
#  'location',
#  'rest_type',
#  'dish_liked',
#  'cuisines',
#  'approx_cost(for two people)']

# %%
##percentage of missing values
for feature in feature_na:
    print('{} has {} missing values'.format(feature,np.round(zomato[feature].isnull().sum()/len(zomato)*100,4)))
# Out:
# rate has 15.0337 missing values
# phone has 2.3358 missing values
# location has 0.0406 missing values
# rest_type has 0.4389 missing values
# dish_liked has 54.2916 missing values
# cuisines has 0.087 missing values
# approx_cost(for two people) has 0.669 missing values

# %%
zomato['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
zomato.dropna(axis='index',subset=['rate'],inplace=True)

# %%
zomato.shape
# Out:
# (43942, 17)

# %%
def split (x):
    return x.split('/')[0]

# %%
zomato['rate']=zomato['rate'].apply(split)

# %%
zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table rate  votes                             phone  \
# 0          Yes        Yes  4.1    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato['rate'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', 'NEW', '2.9', '3.5',
#        '2.6', '3.8 ', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2',
#        '2.3', '3.4 ', '-', '3.6 ', '4.8', '3.9 ', '4.2 ', '4.0 ', '4.1 ',
#        '3.7 ', '3.1 ', '2.9 ', '3.3 ', '2.8 ', '3.5 ', '2.7 ', '2.5 ',
#        '3.2 ', '2.6 ', '4.5 ', '4.3 ', '4.4 ', '4.9', '2.1', '2.0', '1.8',
#        '4.6 ', '4.9 ', '3.0 ', '4.8 ', '2.3 ', '4.7 ', '2.4 ', '2.1 ',
#        '2.2 ', '2.0 ', '1.8 '], dtype=object)

# %%
zomato.replace('NEW',0,inplace=True)

# %%
zomato.replace('-',0,inplace=True)

# %%
zomato['rate'].dtype
# Out:
# dtype('O')

# %%
zomato['rate']=zomato['rate'].astype(float)

# %%
zomato.head(20)
# Out:
#                                                   url  \
# 0   https://www.zomato.com/bangalore/jalsa-banasha...
# 1   https://www.zomato.com/bangalore/spice-elephan...
# 2   https://www.zomato.com/SanchurroBangalore?cont...
# 3   https://www.zomato.com/bangalore/addhuri-udupi...
# 4   https://www.zomato.com/bangalore/grand-village...
# 5   https://www.zomato.com/bangalore/timepass-dinn...
# 6   https://www.zomato.com/bangalore/rosewood-inte...
# 7   https://www.zomato.com/bangalore/onesta-banash...
# 8   https://www.zomato.com/bangalore/penthouse-caf...
# 9   https://www.zomato.com/bangalore/smacznego-ban...
# 10  https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 11  https://www.zomato.com/bangalore/cafe-shuffle-...
# 12  https://www.zomato.com/bangalore/the-coffee-sh...
# 13  https://www.zomato.com/bangalore/caf-eleven-ba...
# 14  https://www.zomato.com/SanchurroBangalore?cont...
# 15  https://www.zomato.com/bangalore/cafe-vivacity...
# ...

# %%
zomato['rate'].dtype
# Out:
# dtype('float64')

# %%
##groupby
zomato_rate=zomato.groupby('name')['rate'].mean().to_frame().reset_index()
zomato_rate.columns=['restaurant','average_rating']
zomato_rate.head()
# Out:
#                              restaurant  average_rating
# 0                          #FeelTheROLL             3.4
# 1                            #L-81 Cafe             3.9
# 2                               #refuel             3.7
# 3                              1000 B.C             3.2
# 4  100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C             3.7

# %%
##distribution rating
sns.displot(zomato_rate['average_rating'])

# %%
##Top restaurant chains
zomato.shape
# Out:
# (43942, 17)

# %%
restaurant_chains=zomato['name'].value_counts()[0:20]
sns.barplot(x=restaurant_chains,y=restaurant_chains.index)
plt.title('Most famous restaurant chains in Begalore')
plt.xlabel('number of outlets')
# Out:
# Text(0.5, 0, 'number of outlets')

# %%
## restaurants not accepting online orders
x=zomato['online_order'].value_counts()
x
# Out:
# Yes    28308
# No     15634
# Name: online_order, dtype: int64

# %%
labels=['accepted','not accepted']

# %%
import plotly.express as px

# %%
px.pie(zomato,values=x,labels=labels,title='zomato online orders')
# Out:
# <div>                            <div id="df06bbff-d3b7-4e30-a5b8-eb113be15c1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df06bbff-d3b7-4e30-a5b8-eb113be15c1d")) {                    Plotly.newPlot(                        "df06bbff-d3b7-4e30-a5b8-eb113be15c1d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"value=%{value}<extra></extra>","legendgroup":"","name":"","showlegend":false,"values":[28308,15634],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.
# ...

# %%
x=zomato['book_table'].value_counts()
x
# Out:
# No     37509
# Yes     6433
# Name: book_table, dtype: int64

# %%
labels=['cannot book', 'can book']

# %%
import plotly.graph_objs as go
from plotly.offline import iplot

# %%
##Ratio between restaurants that provide tables & don't
trace=go.Pie(labels=labels,values=x,hoverinfo='label+percent',textinfo='value',title='restaurants that book tables',titleposition='bottom center')
iplot([trace])
# Out:
# <div>                            <div id="1419981d-9c89-4a7c-9348-fcdec319d9fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1419981d-9c89-4a7c-9348-fcdec319d9fe")) {                    Plotly.newPlot(                        "1419981d-9c89-4a7c-9348-fcdec319d9fe",                        [{"hoverinfo":"label+percent","labels":["cannot book","can book"],"textinfo":"value","title":{"position":"bottom center","text":"restaurants that book tables"},"values":[37509,6433],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":
# ...

# %%
zomato['rest_type'].isna().sum()
# Out:
# 151

# %%
zomato.dropna(axis='index',subset=['rest_type'],inplace=True)

# %%
zomato['rest_type'].isna().sum()
# Out:
# 0

# %%
len(zomato['rest_type'].unique())
# Out:
# 87

# %%
trace1=go.Bar(x=zomato['rest_type'].value_counts().nlargest(20).index,y=zomato['rest_type'].value_counts().nlargest(20))

# %%
iplot([trace1])
# Out:
# <div>                            <div id="9bdca1dd-9dac-449c-87e8-832547f361b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9bdca1dd-9dac-449c-87e8-832547f361b5")) {                    Plotly.newPlot(                        "9bdca1dd-9dac-449c-87e8-832547f361b5",                        [{"x":["Quick Bites","Casual Dining","Cafe","Dessert Parlor","Delivery","Takeaway, Delivery","Casual Dining, Bar","Bakery","Beverage Shop","Bar","Food Court","Bar, Casual Dining","Lounge","Pub","Sweet Shop","Fine Dining","Casual Dining, Cafe","Pub, Casual Dining","Beverage Shop, Quick Bites","Bakery, Quick Bites"],"y":[15073,9923,3527,1939,1791,1472,1141,775,704,661,526,420,396,356,351,343,319,255,244,234],"type":"bar"}],                        {"template":{"data"
# ...

# %%
##highest voted restaurant
zomato.groupby('name')['votes'].sum().nlargest(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='name'>

# %%
trace1=go.Bar(x=zomato.groupby('name')['votes'].sum().nlargest(20).index,y=zomato.groupby('name')['votes'].sum().nlargest(20))
iplot([trace1])
# Out:
# <div>                            <div id="7197ff0a-4ce4-4acc-8967-b1c84f94f365" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7197ff0a-4ce4-4acc-8967-b1c84f94f365")) {                    Plotly.newPlot(                        "7197ff0a-4ce4-4acc-8967-b1c84f94f365",                        [{"x":["Onesta","Truffles","Empire Restaurant","Hammered","The Black Pearl","Meghana Foods","Barbeque Nation","Smally's Resto Cafe","Byg Brewski Brewing Company","Gilly's Restobar","Arbor Brewing Company","House Of Commons","Chutney Chang","Fenny's Lounge And Kitchen","AB's - Absolute Barbecues","Church Street Social","Prost Brew Pub","The Biere Club","Stoner","Koramangala Social"],"y":[347520,301059,229808,180602,172122,129557,108425,102877,99531,98808,92362,9057
# ...

# %%
##total restaurant at different locations
restaurant=[]
location=[]
for key,location_zomato in zomato.groupby('location'):
    location.append(key)
    restaurant.append(len(location_zomato['name'].unique()))

# %%
zomato_total=pd.DataFrame(zip(location,restaurant))
zomato_total.columns=['location','restaurant']
zomato_total.head()
# Out:
#             location  restaurant
# 0                BTM         578
# 1       Banashankari         238
# 2          Banaswadi         150
# 3  Bannerghatta Road         361
# 4       Basavanagudi         195

# %%
##top10 locations
zomato_total.set_index('location',inplace=True)
zomato_total.head()
# Out:
#                    restaurant
# location
# BTM                       578
# Banashankari              238
# Banaswadi                 150
# Bannerghatta Road         361
# Basavanagudi              195

# %%
zomato_total.sort_values(by='restaurant').tail(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='location'>

# %%
##total number of variety of restaurants in bengalore
cuisines=zomato['cuisines'].value_counts()[0:10]
cuisines
# Out:
# North Indian                           2284
# North Indian, Chinese                  2036
# South Indian                           1320
# Cafe                                    653
# Bakery, Desserts                        644
# Biryani                                 632
# South Indian, North Indian, Chinese     601
# Fast Food                               580
# Desserts                                572
# Chinese                                 449
# Name: cuisines, dtype: int64

# %%
trace1=go.Bar(x=zomato['cuisines'].value_counts()[0:10].index,y=zomato['cuisines'].value_counts()[0:10])

# %%
iplot([trace1])
# Out:
# <div>                            <div id="e197e1e1-2777-439d-b70a-69b5a830698b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e197e1e1-2777-439d-b70a-69b5a830698b")) {                    Plotly.newPlot(                        "e197e1e1-2777-439d-b70a-69b5a830698b",                        [{"x":["North Indian","North Indian, Chinese","South Indian","Cafe","Bakery, Desserts","Biryani","South Indian, North Indian, Chinese","Fast Food","Desserts","Chinese"],"y":[2284,2036,1320,653,644,632,601,580,572,449],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{
# ...

# %%
##cost of two people
zomato.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato['approx_cost(for two people)'].isna().sum()
# Out:
# 250

# %%
zomato.dropna(axis='index',subset=['approx_cost(for two people)'],inplace=True)

# %%
zomato['approx_cost(for two people)'].isna().sum()
# Out:
# 0

# %%
zomato['approx_cost(for two people)'].dtype
# Out:
# dtype('O')

# %%
zomato['approx_cost(for two people)'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '1,700', '1,400', '1,350', '2,200', '2,000',
#        '1,800', '1,900', '180', '330', '2,500', '2,100', '3,000', '2,800',
#        '3,400', '50', '40', '1,250', '3,500', '4,000', '2,400', '2,600',
#        '1,450', '70', '3,200', '560', '240', '360', '6,000', '1,050',
#        '2,300', '4,100', '120', '5,000', '3,700', '1,650', '2,700',
#        '4,500'], dtype=object)

# %%
zomato['approx_cost(for two people)']=zomato['approx_cost(for two people)'].apply(lambda x:x.replace(',',''))

# %%
zomato['approx_cost(for two people)']=zomato['approx_cost(for two people)'].astype(int)

# %%
zomato['approx_cost(for two people)'].dtype
# Out:
# dtype('int32')

# %%
sns.displot(zomato['approx_cost(for two people)'])

# %%
##relationship
sns.scatterplot(x='rate',y='approx_cost(for two people)',hue='online_order',data=zomato)
# Out:
# <AxesSubplot:xlabel='rate', ylabel='approx_cost(for two people)'>

# %%
##difference btw votes
sns.boxplot(x='online_order',y='votes',data=zomato)
# Out:
# <AxesSubplot:xlabel='online_order', ylabel='votes'>

# %%
px.box(zomato,x='online_order',y='votes')
# Out:
# <div>                            <div id="b050ad8f-76ae-42cd-9e7d-f99131782a5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b050ad8f-76ae-42cd-9e7d-f99131782a5a")) {                    Plotly.newPlot(                        "b050ad8f-76ae-42cd-9e7d-f99131782a5a",                        [{"alignmentgroup":"True","hovertemplate":"online_order=%{x}<br>votes=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Yes","Yes","Yes","No","No","Yes","No","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","No","No","Yes","No","No","No","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","Yes","No","Yes",
# ...

# %%
##luxurious restaurant bengalore
zomato.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato['approx_cost(for two people)'].min()
# Out:
# 40

# %%
zomato['approx_cost(for two people)'].max()
# Out:
# 6000

# %%
zomato[zomato['approx_cost(for two people)']==6000]['name']
# Out:
# 19139    Le Cirque Signature - The Leela Palace
# 45618    Le Cirque Signature - The Leela Palace
# Name: name, dtype: object

# %%
##expensive
data=zomato.copy()

# %%
data.set_index('name',inplace=True)

# %%
data.head()
# Out:
#                                                                      url  \
# name
# Jalsa                  https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant         https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe        https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana  https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village          https://www.zomato.com/bangalore/grand-village...
#
#                                                                  address  \
# name
# Jalsa                  942, 21st Main Road, 2nd Stage, Banashankari, ...
# Spice Elephant         2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# San Churro Cafe        1112, Next to KIMS Medical College, 17th Cross...
# Addhuri Udupi Bhojana  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# Grand Village          10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
#
#                       online_order book_table  rate  votes  \
# name
# ...

# %%
data['approx_cost(for two people)'].nlargest(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='name'>

# %%
data['approx_cost(for two people)'].nsmallest(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='name'>

# %%
##below 500
data[data['approx_cost(for two people)']<=500]
# Out:
#                                                                                                   url  \
# name
# Addhuri Udupi Bhojana                               https://www.zomato.com/bangalore/addhuri-udupi...
# CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The Alley  https://www.zomato.com/bangalore/caf%C3%A9-dow...
# The Coffee Shack                                    https://www.zomato.com/bangalore/the-coffee-sh...
# Caf-Eleven                                          https://www.zomato.com/bangalore/caf-eleven-ba...
# T3H Cafe                                            https://www.zomato.com/bangalore/t3h-cafe-bana...
# ...                                                                                               ...
# Venice Kerala Restaurant                            https://www.zomato.com/bangalore/venice-kerala...
# Thai & Chinese Fast Food                            https://www.zomato.com/bangalore/thai-chinese-...
# ...

# %%
zomato_budget=data[data['approx_cost(for two people)']<=500].loc[:,('approx_cost(for two people)')]

# %%
zomato_budget=zomato_budget.reset_index()

# %%
zomato_budget.head()
# Out:
#                                                 name  \
# 0                              Addhuri Udupi Bhojana
# 1  CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...
# 2                                   The Coffee Shack
# 3                                         Caf-Eleven
# 4                                           T3H Cafe
#
#    approx_cost(for two people)
# 0                          300
# 1                          500
# 2                          500
# 3                          450
# 4                          300

# %%
##restaurants with good rating & budget friendly
zomato[(zomato['rate']>4)&(zomato['approx_cost(for two people)']<=500)].shape
# Out:
# (2436, 17)

# %%
len(zomato[(zomato['rate']>4)&(zomato['approx_cost(for two people)']<=500)]['name'].unique())
# Out:
# 372

# %%
##total various affordable hotels in all locations of Bengalore
zomato_new=zomato[(zomato['rate']>4)&(zomato['approx_cost(for two people)']<=500)]

# %%
zomato_new.head()
# Out:
#                                                   url  \
# 10  https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 12  https://www.zomato.com/bangalore/the-coffee-sh...
# 34  https://www.zomato.com/bangalore/faasos-banash...
# 51  https://www.zomato.com/bangalore/shree-cool-po...
# 52  https://www.zomato.com/bangalore/corner-house-...
#
#                                               address  \
# 10  12,29 Near PES University Back Gate, D'Souza N...
# 12      6th Block, 3rd Stage, Banashankari, Bangalore
# 34  80, BDA Complex, 2nd Stage, Banashankari, Bang...
# 51  1514, 4th Cross, 7th Main, RPC layout, 2nd Sta...
# 52  808/6-1, 24th A Cross, K.R Road, 2nd Stage, Ba...
#
#                                                  name online_order book_table  \
# 10  CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes         No
# 12                                   The Coffee Shack          Yes        Yes
# ...

# %%
location=[]
total=[]
for loc,location_zomato in zomato_new.groupby('location'):
    location.append(loc)
    total.append(len(location_zomato['name'].unique()))

# %%
location_zomato=pd.DataFrame(zip(location,total))
location_zomato.head()
# Out:
#                    0   1
# 0                BTM  28
# 1       Banashankari  16
# 2          Banaswadi   1
# 3  Bannerghatta Road   9
# 4       Basavanagudi  24

# %%
location_zomato.columns=['location','restaurant']

# %%
location_zomato.head()
# Out:
#             location  restaurant
# 0                BTM          28
# 1       Banashankari          16
# 2          Banaswadi           1
# 3  Bannerghatta Road           9
# 4       Basavanagudi          24

# %%
##best budget restaurant in location
def return_budget(location,restaurant):
    budget=zomato[(zomato['approx_cost(for two people)']<=400)&(zomato['location']==location)&(zomato['rate']>4)&(zomato['rest_type']==restaurant)]
    return (budget['name'].unique())

# %%
return_budget('BTM','Quick Bites')
# Out:
# array(['Swadista Aahar', 'Litti Twist', 'The Shawarma Shop', 'Gorbandh',
#        'Yum In My Tum', 'Chaatimes', "Muthashy's", 'Swad Punjab Da',
#        "Domino's Pizza", 'Roti Wala', 'Andhra Kitchen'], dtype=object)

# %%
restaurant_location=zomato['location'].value_counts()[0:20]
sns.barplot(restaurant_location,restaurant_location.index)
# Out:
# C:\conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='location'>

# %%
##Geographical Analysis

# %%
locations=pd.DataFrame({'Name':zomato['location'].unique()})
locations.head()
# Out:
#                  Name
# 0        Banashankari
# 1        Basavanagudi
# 2         Mysore Road
# 3           Jayanagar
# 4  Kumaraswamy Layout

# %%
# !pip install geopy

# %%
from geopy.geocoders import Nominatim

# %%
geolocator=Nominatim(user_agent='app')

# %%
lat_lon=[]
for location in locations['Name']:
    location=geolocator.geocode(location)
    if location is None:
        lat_lon.append(np.nan)
    else:
            geo=(location.latitude,location.longitude)
            lat_lon.append(geo)

# %%
##Longitude and Latitude for each location of Bengalore
locations['geo_loc']=lat_lon

# %%
locations.head()
# Out:
#                  Name                           geo_loc
# 0        Banashankari          (15.8876779, 75.7046777)
# 1        Basavanagudi          (12.9417261, 77.5755021)
# 2         Mysore Road          (12.9467026, 77.5300705)
# 3           Jayanagar  (27.64392675, 83.05280519687284)
# 4  Kumaraswamy Layout          (12.9081487, 77.5553179)

# %%
locations.shape
# Out:
# (92, 2)

# %%
Rest_locations=pd.DataFrame(zomato['location'].value_counts()).reset_index()
Rest_locations.head()
# Out:
#                    index  location
# 0                    BTM      4210
# 1  Koramangala 5th Block      2358
# 2                    HSR      2102
# 3            Indiranagar      1889
# 4               JP Nagar      1842

# %%
Rest_locations.columns=['Name','Count']

# %%
Rest_locations.head()
# Out:
#                     Name  Count
# 0                    BTM   4210
# 1  Koramangala 5th Block   2358
# 2                    HSR   2102
# 3            Indiranagar   1889
# 4               JP Nagar   1842

# %%
##Merge Dataframe
Restaurant_locations=Rest_locations.merge(locations,on='Name',how='left').dropna()
Restaurant_locations.head()
# Out:
#                     Name  Count                             geo_loc
# 0                    BTM   4210  (45.95485055, -112.49659530324134)
# 1  Koramangala 5th Block   2358            (12.9348429, 77.6189768)
# 2                    HSR   2102                (18.1475, 41.538889)
# 3            Indiranagar   1889            (12.9732913, 77.6404672)
# 4               JP Nagar   1842            (12.2655944, 76.6465404)

# %%
lat,lon=zip(*np.array(Restaurant_locations['geo_loc']))

# %%
type(lat)
# Out:
# tuple

# %%
Restaurant_locations['lat']=lat
Restaurant_locations['lon']=lon

# %%
Restaurant_locations.drop('geo_loc',axis=1,inplace=True)

# %%
Restaurant_locations.head()
# Out:
#                     Name  Count        lat         lon
# 0                    BTM   4210  45.954851 -112.496595
# 1  Koramangala 5th Block   2358  12.934843   77.618977
# 2                    HSR   2102  18.147500   41.538889
# 3            Indiranagar   1889  12.973291   77.640467
# 4               JP Nagar   1842  12.265594   76.646540

# %%
##Generate basemap of Bengalore
# !pip install folium

# %%
import folium
from folium.plugins import HeatMap

# %%
def generatebasemap (default_location=[12.97,77.59],default_zoom_start=12):
    basemap=folium.Map(location=default_location,zoom_start=default_zoom_start)
    return basemap

# %%
basemap=generatebasemap()

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
##Heat map of Rest. in Bengalore
HeatMap(Restaurant_locations[['lat','lon','Count']].values.tolist(),zoom=20,radius=15).add_to(basemap)

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
##Heatmap of North Indian Restaurants
zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table  rate  votes                             phone  \
# 0          Yes        Yes   4.1    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato2=zomato[zomato['cuisines']=='North Indian']
zomato2.head()
# Out:
#                                                   url  \
# 5   https://www.zomato.com/bangalore/timepass-dinn...
# 50  https://www.zomato.com/bangalore/petoo-banasha...
# 72  https://www.zomato.com/bangalore/spicy-tandoor...
# 87  https://www.zomato.com/bangalore/krishna-sagar...
# 94  https://www.zomato.com/bangalore/nandhini-delu...
#
#                                               address             name  \
# 5   37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...  Timepass Dinner
# 50  276, Ground Floor, 100 Feet Outer Ring Road, B...            Petoo
# 72  Opposite ICICi Bank, Hanuman Nagar, Banashanka...    Spicy Tandoor
# 87  38, 22nd Main, 22nd Cross, Opposite BDA, 2nd S...    Krishna Sagar
# 94  304, Opposite Apollo Public School, 100 Feet R...  Nandhini Deluxe
#
#    online_order book_table  rate  votes                             phone  \
# 5           Yes         No   3.8    286  +91 9980040002\r\n+91 9980063005
# ...

# %%
North_india=zomato2.groupby('location',as_index=False)['url'].agg('count')

# %%
North_india.head()
# Out:
#             location  url
# 0                BTM  262
# 1       Banashankari   35
# 2          Banaswadi    5
# 3  Bannerghatta Road   60
# 4       Basavanagudi   17

# %%
North_india.columns=['Name','Count']

# %%
North_india.head()
# Out:
#                 Name  Count
# 0                BTM    262
# 1       Banashankari     35
# 2          Banaswadi      5
# 3  Bannerghatta Road     60
# 4       Basavanagudi     17

# %%
##merge
North_india=North_india.merge(locations,on='Name',how='left').dropna()
North_india.head(10)
# Out:
#                  Name  Count                             geo_loc
# 0                 BTM    262  (45.95485055, -112.49659530324134)
# 1        Banashankari     35            (15.8876779, 75.7046777)
# 2           Banaswadi      5            (13.0141618, 77.6518539)
# 3   Bannerghatta Road     60            (12.9211978, 77.6002222)
# 4        Basavanagudi     17            (12.9417261, 77.5755021)
# 5  Basaveshwara Nagar      1            (12.2950874, 76.6149845)
# 6           Bellandur    131           (12.93103185, 77.6782471)
# 7        Bommanahalli      6            (12.9089453, 77.6239038)
# 8        Brigade Road     39              (40.28745, -76.964526)
# 9         Brookefield     42           (33.5935063, -79.0345627)

# %%
North_india['lat'],North_india['lon']=zip(*North_india['geo_loc'].values)

# %%
North_india.head()
# Out:
#                 Name  Count                             geo_loc        lat  \
# 0                BTM    262  (45.95485055, -112.49659530324134)  45.954851
# 1       Banashankari     35            (15.8876779, 75.7046777)  15.887678
# 2          Banaswadi      5            (13.0141618, 77.6518539)  13.014162
# 3  Bannerghatta Road     60            (12.9211978, 77.6002222)  12.921198
# 4       Basavanagudi     17            (12.9417261, 77.5755021)  12.941726
#
#           lon
# 0 -112.496595
# 1   75.704678
# 2   77.651854
# 3   77.600222
# 4   77.575502

# %%
North_india.drop('geo_loc',axis=1,inplace=True)

# %%
North_india.head()
# Out:
#                 Name  Count        lat         lon
# 0                BTM    262  45.954851 -112.496595
# 1       Banashankari     35  15.887678   75.704678
# 2          Banaswadi      5  13.014162   77.651854
# 3  Bannerghatta Road     60  12.921198   77.600222
# 4       Basavanagudi     17  12.941726   77.575502

# %%
##HeatMap
basemap=generatebasemap()
HeatMap(North_india[['lat','lon','Count']].values.tolist(),zoom=20,radius=15).add_to(basemap)
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
##Most Popular Casual Dining Restaurant Chains
zomato_1=zomato.groupby(['rest_type','name']).agg('count')
zomato_1
# Out:
#                                                 url  address  online_order  \
# rest_type          name
# Bakery             7th Heaven                     2        2             2
#                    A Little For Love              1        1             1
#                    Adarsh Bakery                  2        2             2
#                    Adi's Cake N Cafe              2        2             2
#                    Albert Bakery                  1        1             1
# ...                                             ...      ...           ...
# Takeaway, Delivery Yumlane                        2        2             2
#                    Yumme Veg                      2        2             2
#                    Zamorin's Mappillah Biryani    1        1             1
#                    Zu's Doner Kebaps              1        1             1
#                    eat.fit                        2        2             2
#
# ...

# %%
dataset=zomato_1.sort_values(['url'],ascending=False).groupby(['rest_type'],as_index=False).apply(lambda x:x.sort_values(by='url',ascending=False))['url'].reset_index().rename(columns={'url':'count'})

# %%
dataset
# Out:
#       level_0           rest_type                        name  count
# 0           0              Bakery                   Just Bake     44
# 1           0              Bakery                   Warm Oven     28
# 2           0              Bakery        INDULGE by InnerChef     28
# 3           0              Bakery              Karachi Bakery     26
# 4           0              Bakery                    CakeZone     21
# ...       ...                 ...                         ...    ...
# 7707       86  Takeaway, Delivery              Agraharam Meal      1
# 7708       86  Takeaway, Delivery  Adyar Ananda Bhavan Sweets      1
# 7709       86  Takeaway, Delivery                      Faasos      1
# 7710       86  Takeaway, Delivery         @North Parontha Hut      1
# 7711       86  Takeaway, Delivery            Lucky Singh & Co      1
#
# [7712 rows x 4 columns]

# %%
casual=dataset[dataset['rest_type']=='Casual Dining']
casual
# Out:
#       level_0      rest_type  \
# 1001       24  Casual Dining
# 1002       24  Casual Dining
# 1003       24  Casual Dining
# 1004       24  Casual Dining
# 1005       24  Casual Dining
# ...       ...            ...
# 2635       24  Casual Dining
# 2636       24  Casual Dining
# 2637       24  Casual Dining
# 2638       24  Casual Dining
# 2639       24  Casual Dining
#
#                                                    name  count
# 1001                                  Empire Restaurant     58
# 1002                                      Beijing Bites     48
# 1003                                 Mani's Dum Biryani     47
# 1004                                          Chung Wah     46
# 1005                                       Oye Amritsar     41
# ...                                                 ...    ...
# 2635  Uppercut - Sheraton Grand Bengaluru Whitefield...      1
# 2636                                   Utsav Restaurant      1
# ...
